# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([5,10,15,20])
print(series)
print(type(series))
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
series[3]
# Out:
# 20

# %%
cad = pd.Series(['p', 'e', 'r',' r',' o'])
cad
# Out:
# 0     p
# 1     e
# 2     r
# 3     r
# 4     o
# dtype: object

# %%
ls= ['Hola', 'mundo', 'desgraciado']
df=pd.DataFrame(ls)
print(df)
# Out:
#              0
# 0         Hola
# 1        mundo
# 2  desgraciado

# %%
data={'Nombre':['Juan','Ana','Jose'], 'Edad':[2,43,24],
'Pais':['Mex', 'Col', 'Ven']}
df= pd.DataFrame(data)
df
# Out:
#   Nombre  Edad Pais
# 0   Juan     2  Mex
# 1    Ana    43  Col
# 2   Jose    24  Ven

# %%
print(df[['Nombre', 'Pais']])
# Out:
#   Nombre Pais
# 0   Juan  Mex
# 1    Ana  Col
# 2   Jose  Ven

# %%
data=pd.read_csv('C:/Users/52222/Documents/Platzi/Fundamentos Practicos ML/canciones.csv')

# %%
data.head(10)
# Out:
#                       id                          name        artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan          Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!   XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)    Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)    Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings          Drake
# 5  7dt6x5M1jzdTEt8oCbisT                    Better Now    Post Malone
# 6  58q2HKrzhC3ozto2nDdN4                     I Like It        Cardi B
# 7  7ef4DlsgrMEH11cDZd32M      One Kiss (with Dua Lipa)  Calvin Harris
# 8  76cy1WJvNGJTj78UqeA5z                         IDGAF       Dua Lipa
# 9  08bNPGLD8AhKpnnERrAc6                       FRIENDS     Marshmello
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449   7.0    -9.211   1.0       0.1090        0.0332
# ...

# %%
artista=data.artists #lee toda la columna y solo escoges 
artista[5]
# Out:
# 'Post Malone'

# %%
info= data.iloc[15] #Todo lo relacionado con la seleccion
info
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                      8.0
# loudness                              -4.946
# mode                                     1.0
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                         232187.0
# time_signature                           4.0
# Name: 15, dtype: object

# %%
data.shape
# Out:
# (100, 16)

# %%
data.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
data['tempo'].describe()
# Out:
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
data.sort_index(axis=0, ascending= False)
# Out:
#                        id                               name       artists  \
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# ..                    ...                                ...           ...
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
#
# ...

# %%
#selecciomar 3 columans de preferencia y ordenalas de manera ascendete

# %%
subset=data[['id', 'name', 'key']]
subset
# Out:
#                        id                               name   key
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan   7.0
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!   8.0
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   5.0
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   8.0
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings   1.0
# ..                    ...                                ...   ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars  10.0
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)   3.0
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer   0.0
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit  11.0
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright  11.0
#
# [100 rows x 3 columns]

# %%
subset.sort_values(by=['id','name'],axis=0,ascending=True) ## axis, 0= azis, 1=column labels
# Out:
#                        id                             name  key
# 9   08bNPGLD8AhKpnnERrAc6                          FRIENDS  9.0
# 14  09IStsImFySgyp0pIQdqA                       The Middle  7.0
# 39  0E9ZjEAyAwOXZ7wJC0PD3                       In My Mind  6.0
# 18  0JP9xo3adEtGSdUEISisz                        Moonlight  9.0
# 61  0TlLq3lA83rQOYtrqBqSc                          Nonstop  7.0
# ..                    ...                              ...  ...
# 28  7m9OqQk4RVRkw9JJdeAw9                   Jocelyn Flores  0.0
# 25  7qiZfU4dY1lWllzX7mPBI                     Shape of You  1.0
# 50  7sO5G9EABYOXQKNPNiE9N  Ric Flair Drip (& Metro Boomin)  9.0
# 22  7uzmGiiJyRfuViKKK3lVm                             Mine  4.0
# 64  7vGuf3Y35N4wmASOKLUVV                          Silence  4.0
#
# [100 rows x 3 columns]
